# %% [markdown]
# # Progetto CV

# %%
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread("img/first task/C0_000001.png", cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='gray', vmin=0, vmax=255)
plt.show()
